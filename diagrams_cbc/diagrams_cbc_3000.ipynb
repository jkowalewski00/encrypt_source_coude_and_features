# %%
import os
import pandas as pd
import numpy as np
import scipy.stats as stats
from collections import Counter
from math import log2

# %% [markdown]
# Diagrams for 1000 files per format in ECB mode (1 key per algorithm)

# %%
df_cbc_3000_1key = pd.DataFrame(pd.read_csv('../features_cbc/features_cbc_3000/features_cbc_3000_1key_csv/features_all.csv'))
df_cbc_3000_1key
# Out:
#                 file_name    format   entropy        mean     variance  \
# 0         file0873.py.enc  pyth_cbc  7.959646  127.532717  5435.571132
# 1         file0973.py.enc  pyth_cbc  7.863339  125.566621  5425.498309
# 2         file0666.py.enc  pyth_cbc  7.976577  127.976043  5349.670227
# 3         file0766.py.enc  pyth_cbc  7.948873  127.610900  5572.893341
# 4         file0605.py.enc  pyth_cbc  7.959486  126.795370  5494.078497
# ...                   ...       ...       ...         ...          ...
# 17995  image_0519.bmp.enc   bmp_cbc  7.999436  127.654134  5465.018813
# 17996  image_0471.bmp.enc   bmp_cbc  7.998370  127.798898  5450.350026
# 17997  image_0509.bmp.enc   bmp_cbc  7.999021  127.376662  5469.116444
# 17998  image_0152.bmp.enc   bmp_cbc  7.998431  127.490142  5485.339283
# 17999  image_0142.bmp.enc   bmp_cbc  7.997740  127.815456  5483.913451
#
#          std_dev  skewness  kurtosis    energy        rms  ...  histogram_247  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_cbc_3000_1key["algorithm"].unique()):
    subset = df_cbc_3000_1key[df_cbc_3000_1key["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
#plt.title("Histogram bajtów dla różnych algorytmów i wszystkich formatów plików (3000 plików na format, jeden klucz szyfrujący, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność bajtów")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_cbc_3000_1key["algorithm"], y=df_cbc_3000_1key["entropy"])
plt.xticks(rotation=45)
#plt.title("Entropia w trybie CBC dla różnych algorytmów i wszystkich formatów plików 3000 plików na format, jeden klucz szyfrujący")
plt.show()

# %%
import matplotlib.pyplot as plt

algorithms = df_cbc_3000_1key["algorithm"].unique()
algorithms = [algo for algo in algorithms if algo != "NONE"]

plt.figure(figsize=(15, 5))
for algo in algorithms:
    subset = df_cbc_3000_1key[df_cbc_3000_1key["algorithm"] == algo]
    avg_hist = subset.iloc[:, 9:265].mean()
    plt.plot(range(256), avg_hist, label=algo)
plt.xlim(0, 255)
plt.xlabel("Wartości bajtów")
plt.ylabel("Średnia liczność")
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Data frame with 1000 files *.bmp encrypted in ECB mode using 1 key - features

# %%
df_bmp_cbc_3000_1key = pd.DataFrame(pd.read_csv('../features_cbc/features_cbc_3000/features_cbc_3000_1key_csv/features_bmp_cbc.csv'))
df_bmp_cbc_3000_1key
# Out:
#                file_name   format   entropy        mean     variance  \
# 0     image_1064.bmp.enc  bmp_cbc  7.999294  127.177725  5453.043832
# 1     image_1074.bmp.enc  bmp_cbc  7.999182  127.537812  5464.451975
# 2     image_0770.bmp.enc  bmp_cbc  7.998849  127.782641  5467.391847
# 3     image_0608.bmp.enc  bmp_cbc  7.999125  127.286892  5444.680006
# 4     image_0760.bmp.enc  bmp_cbc  7.998821  127.267919  5472.318942
# ...                  ...      ...       ...         ...          ...
# 2995  image_0519.bmp.enc  bmp_cbc  7.999436  127.654134  5465.018813
# 2996  image_0471.bmp.enc  bmp_cbc  7.998370  127.798898  5450.350026
# 2997  image_0509.bmp.enc  bmp_cbc  7.999021  127.376662  5469.116444
# 2998  image_0152.bmp.enc  bmp_cbc  7.998431  127.490142  5485.339283
# 2999  image_0142.bmp.enc  bmp_cbc  7.997740  127.815456  5483.913451
#
#         std_dev  skewness  kurtosis    energy        rms  ...  histogram_247  \
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_bmp_cbc_3000_1key["algorithm"].unique()):
    subset = df_bmp_cbc_3000_1key[df_bmp_cbc_3000_1key["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.bmp, jeden klucz szyfrujący, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_bmp_cbc_3000_1key["algorithm"], y=df_bmp_cbc_3000_1key["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie CBC dla różnych algorytmów i 3000 plików *.bmp szyfrowanych jednym kluczem dla każdego algorytmu")
plt.show()

# %%
df_csv_cbc_3000_1key = pd.DataFrame(pd.read_csv('../features_cbc/features_cbc_3000/features_cbc_3000_1key_csv/features_csv_cbc.csv'))
df_csv_cbc_3000_1key
# Out:
#              file_name   format   entropy        mean     variance    std_dev  \
# 0     file0715.csv.enc  csv_cbc  6.003258  121.819444  5227.092400  72.298633
# 1     file0705.csv.enc  csv_cbc  6.087217  131.784091  6271.055656  79.189997
# 2     file1179.csv.enc  csv_cbc  6.053056  135.450000  5279.622500  72.661011
# 3     file1001.csv.enc  csv_cbc  6.339769  117.875000  4538.147837  67.365776
# 4     file1169.csv.enc  csv_cbc  6.389901  119.410714  4248.509885  65.180594
# ...                ...      ...       ...         ...          ...        ...
# 2995  file0414.csv.enc  csv_cbc  6.628830  118.085938  5130.859802  71.630020
# 2996  file0251.csv.enc  csv_cbc  6.526018  140.830357  4991.944436  70.653694
# 2997  file0329.csv.enc  csv_cbc  5.903056  130.725000  5534.049375  74.391192
# 2998  file0241.csv.enc  csv_cbc  6.096928  124.500000  4854.875000  69.676933
# 2999  file0339.csv.enc  csv_cbc  6.272463  129.635417  6487.398329  80.544387
#
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_csv_cbc_3000_1key["algorithm"].unique()):
    subset = df_csv_cbc_3000_1key[df_csv_cbc_3000_1key["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.csv, jeden klucz szyfrujący, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_csv_cbc_3000_1key["algorithm"], y=df_csv_cbc_3000_1key["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie CBC dla różnych algorytmów i 3000 plików *.csv szyfrowanych jednym kluczem dla każdego algorytmu")
plt.show()

# %%
df_html_cbc_3000_1key = pd.DataFrame(pd.read_csv('../features_cbc/features_cbc_3000/features_cbc_3000_1key_csv/features_html_cbc.csv'))
df_html_cbc_3000_1key
# Out:
#               file_name    format   entropy        mean     variance  \
# 0     file1072.html.enc  html_cbc  7.976922  127.030827  5470.848058
# 1     file1073.html.enc  html_cbc  7.946781  126.576039  5487.269382
# 2     file0674.html.enc  html_cbc  7.927999  123.000676  5442.798648
# 3     file0882.html.enc  html_cbc  7.910275  125.867077  5471.283388
# 4     file0883.html.enc  html_cbc  7.980762  127.247864  5406.900626
# ...                 ...       ...       ...         ...          ...
# 2995  file0536.html.enc  html_cbc  7.796911  129.756629  5583.186036
# 2996  file0205.html.enc  html_cbc  7.981757  127.130031  5425.958518
# 2997  file0063.html.enc  html_cbc  7.814098  131.914613  5096.752392
# 2998  file0062.html.enc  html_cbc  7.970232  127.317054  5421.662825
# 2999  file0204.html.enc  html_cbc  7.975168  127.059682  5476.590700
#
#         std_dev  skewness  kurtosis   energy        rms  ...  histogram_247  \
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_html_cbc_3000_1key["algorithm"].unique()):
    subset = df_html_cbc_3000_1key[df_html_cbc_3000_1key["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.html, jeden klucz szyfrujący, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_html_cbc_3000_1key["algorithm"], y=df_html_cbc_3000_1key["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie CBC dla różnych algorytmów i 1800 plików *.html szyfrowanych jednym kluczem dla każdego algorytmu")
plt.show()

# %%
df_pyth_cbc_3000_1key = pd.DataFrame(pd.read_csv('../features_cbc/features_cbc_3000/features_cbc_3000_1key_csv/features_pyth_cbc.csv'))
df_pyth_cbc_3000_1key
# Out:
#             file_name    format   entropy        mean     variance    std_dev  \
# 0     file0873.py.enc  pyth_cbc  7.959646  127.532717  5435.571132  73.726326
# 1     file0973.py.enc  pyth_cbc  7.863339  125.566621  5425.498309  73.657982
# 2     file0666.py.enc  pyth_cbc  7.976577  127.976043  5349.670227  73.141440
# 3     file0766.py.enc  pyth_cbc  7.948873  127.610900  5572.893341  74.651814
# 4     file0605.py.enc  pyth_cbc  7.959486  126.795370  5494.078497  74.122051
# ...               ...       ...       ...         ...          ...        ...
# 2995  file0593.py.enc  pyth_cbc  7.977483  127.843223  5467.792536  73.944523
# 2996  file0108.py.enc  pyth_cbc  7.971683  128.370494  5486.709682  74.072327
# 2997  file0008.py.enc  pyth_cbc  7.981404  126.397986  5575.486752  74.669182
# 2998  file0116.py.enc  pyth_cbc  7.972213  127.476896  5437.329862  73.738252
# 2999  file0016.py.enc  pyth_cbc  7.982851  127.484603  5542.109366  74.445345
#
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_pyth_cbc_3000_1key["algorithm"].unique()):
    subset = df_pyth_cbc_3000_1key[df_pyth_cbc_3000_1key["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.py, jeden klucz szyfrujący, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_pyth_cbc_3000_1key["algorithm"], y=df_pyth_cbc_3000_1key["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie CBC dla różnych algorytmów i 1800 plików *.py szyfrowanych jednym kluczem dla każdego algorytmu")
plt.show()

# %%
df_txt_cbc_3000_1key = pd.DataFrame(pd.read_csv('../features_cbc/features_cbc_3000/features_cbc_3000_1key_csv/features_txt_cbc.csv'))
df_txt_cbc_3000_1key
# Out:
#              file_name   format   entropy        mean     variance    std_dev  \
# 0     file0867.txt.enc  txt_cbc  7.980241  128.013840  5459.192376  73.886348
# 1     file0877.txt.enc  txt_cbc  7.979173  127.356018  5475.146871  73.994235
# 2     file0712.txt.enc  txt_cbc  7.964722  128.260766  5317.278493  72.919672
# 3     file0702.txt.enc  txt_cbc  7.962040  126.856567  5523.483843  74.320144
# 4     file1006.txt.enc  txt_cbc  7.953969  126.861979  5459.225742  73.886573
# ...                ...      ...       ...         ...          ...        ...
# 2995  file0246.txt.enc  txt_cbc  7.935975  129.571053  5564.381136  74.594780
# 2996  file0397.txt.enc  txt_cbc  7.928611  127.650650  5558.829183  74.557556
# 2997  file0387.txt.enc  txt_cbc  7.957266  126.888465  5395.580802  73.454617
# 2998  file0189.txt.enc  txt_cbc  7.967190  127.724425  5523.876104  74.322783
# 2999  file0199.txt.enc  txt_cbc  7.610397  128.193548  5475.418184  73.996069
#
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_txt_cbc_3000_1key["algorithm"].unique()):
    subset = df_txt_cbc_3000_1key[df_txt_cbc_3000_1key["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.txt, jeden klucz szyfrujący, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_txt_cbc_3000_1key["algorithm"], y=df_txt_cbc_3000_1key["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie CBC dla różnych algorytmów i 3000 plików *.txt szyfrowanych jednym kluczem dla każdego algorytmu")
plt.show()

# %%
df_wav_cbc_3000_1key = pd.DataFrame(pd.read_csv('../features_cbc/features_cbc_1800/features_cbc_1800_1key_csv/features_wav_cbc.csv'))
df_wav_cbc_3000_1key
# Out:
#              file_name   format   entropy        mean     variance    std_dev  \
# 0     file0580.wav.enc  wav_cbc  7.997889  127.607211  5468.263297  73.947707
# 1     file0590.wav.enc  wav_cbc  7.998875  127.537103  5448.094081  73.811206
# 2     file0441.wav.enc  wav_cbc  7.999466  127.418108  5453.455080  73.847512
# 3     file0539.wav.enc  wav_cbc  7.999330  127.425530  5462.081737  73.905898
# 4     file0451.wav.enc  wav_cbc  7.998956  127.578512  5451.100967  73.831572
# ...                ...      ...       ...         ...          ...        ...
# 1795  file0211.wav.enc  wav_cbc  7.997863  127.406029  5456.058076  73.865134
# 1796  file0263.wav.enc  wav_cbc  7.998984  127.363712  5467.195146  73.940484
# 1797  file0273.wav.enc  wav_cbc  7.997913  127.642004  5493.049234  74.115108
# 1798  file0105.wav.enc  wav_cbc  7.998902  127.662537  5470.237499  73.961054
# 1799  file0115.wav.enc  wav_cbc  7.997881  127.890316  5462.178970  73.906556
#
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_wav_cbc_3000_1key["algorithm"].unique()):
    subset = df_wav_cbc_3000_1key[df_wav_cbc_3000_1key["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.wav, jeden klucz szyfrujący, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_wav_cbc_3000_1key["algorithm"], y=df_wav_cbc_3000_1key["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie CBC dla różnych algorytmów i 3000 plików *.wav szyfrowanych jednym kluczem dla każdego algorytmu")
plt.show()

# %% [markdown]
# Diagrams for 1000 files per format in ECB mode (3 keys per algorithm)

# %%
df_all_cbc_3000_3keys = pd.DataFrame(pd.read_csv('../features_cbc/features_cbc_3000/features_cbc_3000_3keys_csv/features_all.csv'))
df_all_cbc_3000_3keys
# Out:
#                 file_name    format   entropy        mean     variance  \
# 0         file0873.py.enc  pyth_cbc  7.962755  128.662455  5482.382904
# 1         file0973.py.enc  pyth_cbc  7.850743  126.068681  5561.103799
# 2         file0666.py.enc  pyth_cbc  7.969428  126.999014  5610.216318
# 3         file0766.py.enc  pyth_cbc  7.952636  127.524946  5325.444063
# 4         file0605.py.enc  pyth_cbc  7.952594  126.337731  5335.704687
# ...                   ...       ...       ...         ...          ...
# 17995  image_0519.bmp.enc   bmp_cbc  7.999363  127.287527  5443.809064
# 17996  image_0471.bmp.enc   bmp_cbc  7.998694  127.836398  5460.604500
# 17997  image_0509.bmp.enc   bmp_cbc  7.999229  127.436450  5462.789399
# 17998  image_0152.bmp.enc   bmp_cbc  7.998160  127.378946  5473.565156
# 17999  image_0142.bmp.enc   bmp_cbc  7.997825  127.846759  5479.761999
#
#          std_dev  skewness  kurtosis    energy        rms  ...  histogram_247  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_all_cbc_3000_3keys["algorithm"].unique()):
    subset = df_all_cbc_3000_3keys[df_all_cbc_3000_3keys["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
#plt.title("Histogram bajtów dla różnych algorytmów i wszystkich formatów plików, 3000 plików na format, trzy klucze szyfrujące na algorytm, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność bajtów")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_all_cbc_3000_3keys["algorithm"], y=df_all_cbc_3000_3keys["entropy"])
plt.xticks(rotation=45)
#plt.title("Entropia w trybie CBC dla różnych algorytmów i wszystkich formatów plików, 3000 plików na format, trzy klucze szyfrujące na algorytm")
plt.show()

# %%
import matplotlib.pyplot as plt

algorithms = df_all_cbc_3000_3keys["algorithm"].unique()
algorithms = [algo for algo in algorithms if algo != "NONE"]

plt.figure(figsize=(15, 5))
for algo in algorithms:
    subset = df_all_cbc_3000_3keys[df_all_cbc_3000_3keys["algorithm"] == algo]
    avg_hist = subset.iloc[:, 9:265].mean()
    plt.plot(range(256), avg_hist, label=algo)
plt.xlim(0, 255)
plt.xlabel("Wartości bajtów")
plt.ylabel("Średnia liczność")
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_bmp_cbc_3000_3keys = pd.DataFrame(pd.read_csv('../features_cbc/features_cbc_3000/features_cbc_3000_3keys_csv/features_bmp_cbc.csv'))
df_bmp_cbc_3000_3keys
# Out:
#                file_name   format   entropy        mean     variance  \
# 0     image_1064.bmp.enc  bmp_cbc  7.999382  127.429746  5465.150960
# 1     image_1074.bmp.enc  bmp_cbc  7.999133  127.471361  5458.085812
# 2     image_0770.bmp.enc  bmp_cbc  7.998957  127.655370  5442.596166
# 3     image_0608.bmp.enc  bmp_cbc  7.999025  127.507559  5447.429693
# 4     image_0760.bmp.enc  bmp_cbc  7.998790  127.656353  5463.298600
# ...                  ...      ...       ...         ...          ...
# 2995  image_0519.bmp.enc  bmp_cbc  7.999363  127.287527  5443.809064
# 2996  image_0471.bmp.enc  bmp_cbc  7.998694  127.836398  5460.604500
# 2997  image_0509.bmp.enc  bmp_cbc  7.999229  127.436450  5462.789399
# 2998  image_0152.bmp.enc  bmp_cbc  7.998160  127.378946  5473.565156
# 2999  image_0142.bmp.enc  bmp_cbc  7.997825  127.846759  5479.761999
#
#         std_dev  skewness  kurtosis    energy        rms  ...  histogram_247  \
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_bmp_cbc_3000_3keys["algorithm"].unique()):
    subset = df_bmp_cbc_3000_3keys[df_bmp_cbc_3000_3keys["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.bmp, trzy klucze szyfrujące na algorytm, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_bmp_cbc_3000_3keys["algorithm"], y=df_bmp_cbc_3000_3keys["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie CBC dla różnych algorytmów i 3000 plików *.bmp szyfrowanych trzema kluczami dla każdego algorytmu")
plt.show()

# %%
df_csv_cbc_3000_3keys = pd.DataFrame(pd.read_csv('../features_cbc/features_cbc_3000/features_cbc_3000_3keys_csv/features_csv_cbc.csv'))
df_csv_cbc_3000_3keys
# Out:
#              file_name   format   entropy        mean     variance    std_dev  \
# 0     file0715.csv.enc  csv_cbc  5.947703  124.013889  6282.735918  79.263711
# 1     file0705.csv.enc  csv_cbc  6.200853  127.193182  5701.201317  75.506300
# 2     file1179.csv.enc  csv_cbc  5.912492  126.787500  4734.542344  68.808011
# 3     file1001.csv.enc  csv_cbc  6.378230  115.798077  5259.526535  72.522593
# 4     file1169.csv.enc  csv_cbc  6.383161  128.142857  4898.247449  69.987481
# ...                ...      ...       ...         ...          ...        ...
# 2995  file0414.csv.enc  csv_cbc  6.533012  128.375000  5226.093750  72.291727
# 2996  file0251.csv.enc  csv_cbc  6.340706  135.267857  5852.999681  76.504900
# 2997  file0329.csv.enc  csv_cbc  5.928056  116.512500  4819.424844  69.422077
# 2998  file0241.csv.enc  csv_cbc  6.121928  130.637500  5358.856094  73.204208
# 2999  file0339.csv.enc  csv_cbc  6.207206  125.677083  5424.531141  73.651416
#
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_csv_cbc_3000_3keys["algorithm"].unique()):
    subset = df_csv_cbc_3000_3keys[df_csv_cbc_3000_3keys["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.csv, trzy klucze szyfrujące na algorytm, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_csv_cbc_3000_3keys["algorithm"], y=df_csv_cbc_3000_3keys["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie CBC dla różnych algorytmów i 3000 plików *.csv szyfrowanych trzema kluczami dla każdego algorytmu")
plt.show()

# %%
df_html_cbc_3000_3keys = pd.DataFrame(pd.read_csv('../features_cbc/features_cbc_3000/features_cbc_3000_3keys_csv/features_html_cbc.csv'))
df_html_cbc_3000_3keys
# Out:
#               file_name    format   entropy        mean     variance  \
# 0     file1072.html.enc  html_cbc  7.975896  126.216997  5442.020248
# 1     file1073.html.enc  html_cbc  7.950116  127.344639  5433.146541
# 2     file0674.html.enc  html_cbc  7.934053  128.901351  5365.963241
# 3     file0882.html.enc  html_cbc  7.899309  127.683979  5583.165976
# 4     file0883.html.enc  html_cbc  7.979749  127.934601  5483.474669
# ...                 ...       ...       ...         ...          ...
# 2995  file0536.html.enc  html_cbc  7.841813  125.568182  5522.476412
# 2996  file0205.html.enc  html_cbc  7.981866  127.845008  5474.782479
# 2997  file0063.html.enc  html_cbc  7.806865  125.258803  5404.941824
# 2998  file0062.html.enc  html_cbc  7.971031  128.413945  5357.419102
# 2999  file0204.html.enc  html_cbc  7.976314  128.167264  5525.774533
#
#         std_dev  skewness  kurtosis   energy        rms  ...  histogram_247  \
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_html_cbc_3000_3keys["algorithm"].unique()):
    subset = df_html_cbc_3000_3keys[df_html_cbc_3000_3keys["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.html, trzy klucze szyfrujące na algorytm, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_html_cbc_3000_3keys["algorithm"], y=df_html_cbc_3000_3keys["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie CBC dla różnych algorytmów i 3000 plików *.html szyfrowanych trzema kluczami dla każdego algorytmu")
plt.show()

# %%
df_pyth_cbc_3000_3keys = pd.DataFrame(pd.read_csv('../features_cbc/features_cbc_3000/features_cbc_3000_3keys_csv/features_pyth_cbc.csv'))
df_pyth_cbc_3000_3keys
# Out:
#             file_name    format   entropy        mean     variance    std_dev  \
# 0     file0873.py.enc  pyth_cbc  7.962755  128.662455  5482.382904  74.043115
# 1     file0973.py.enc  pyth_cbc  7.850743  126.068681  5561.103799  74.572809
# 2     file0666.py.enc  pyth_cbc  7.969428  126.999014  5610.216318  74.901377
# 3     file0766.py.enc  pyth_cbc  7.952636  127.524946  5325.444063  72.975640
# 4     file0605.py.enc  pyth_cbc  7.952594  126.337731  5335.704687  73.045908
# ...               ...       ...       ...         ...          ...        ...
# 2995  file0593.py.enc  pyth_cbc  7.977468  128.409283  5480.557962  74.030791
# 2996  file0108.py.enc  pyth_cbc  7.970962  126.476308  5416.060195  73.593887
# 2997  file0008.py.enc  pyth_cbc  7.974618  126.419680  5512.022991  74.243000
# 2998  file0116.py.enc  pyth_cbc  7.975755  126.557025  5568.815658  74.624498
# 2999  file0016.py.enc  pyth_cbc  7.982632  126.262358  5423.606614  73.645140
#
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_pyth_cbc_3000_3keys["algorithm"].unique()):
    subset = df_pyth_cbc_3000_3keys[df_pyth_cbc_3000_3keys["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.py, trzy klucze szyfrujące na algorytm, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_pyth_cbc_3000_3keys["algorithm"], y=df_pyth_cbc_3000_3keys["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie CBC dla różnych algorytmów i 3000 plików *.py szyfrowanych trzema kluczami dla każdego algorytmu")
plt.show()

# %%
df_txt_cbc_3000_3keys = pd.DataFrame(pd.read_csv('../features_cbc/features_cbc_3000/features_cbc_3000_3keys_csv/features_txt_cbc.csv'))
df_txt_cbc_3000_3keys
# Out:
#              file_name   format   entropy        mean     variance    std_dev  \
# 0     file0867.txt.enc  txt_cbc  7.979539  127.949760  5481.099590  74.034449
# 1     file0877.txt.enc  txt_cbc  7.979182  126.908865  5493.037316  74.115028
# 2     file0712.txt.enc  txt_cbc  7.961521  125.251196  5508.349580  74.218256
# 3     file0702.txt.enc  txt_cbc  7.962490  127.727343  5443.543937  73.780376
# 4     file1006.txt.enc  txt_cbc  7.957766  127.031033  5569.609497  74.629816
# ...                ...      ...       ...         ...          ...        ...
# 2995  file0246.txt.enc  txt_cbc  7.938358  128.032566  5522.005847  74.310200
# 2996  file0397.txt.enc  txt_cbc  7.929104  125.846098  5599.132384  74.827351
# 2997  file0387.txt.enc  txt_cbc  7.949661  128.067835  5526.472278  74.340247
# 2998  file0189.txt.enc  txt_cbc  7.970616  127.522858  5441.291997  73.765114
# 2999  file0199.txt.enc  txt_cbc  7.536119  130.072581  5378.704409  73.339651
#
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_txt_cbc_3000_3keys["algorithm"].unique()):
    subset = df_txt_cbc_3000_3keys[df_txt_cbc_3000_3keys["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.txt, trzy klucze szyfrujące na algorytm, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_txt_cbc_3000_3keys["algorithm"], y=df_txt_cbc_3000_3keys["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie ECB dla różnych algorytmów i 3000 plików *.txt szyfrowanych trzema kluczami dla każdego algorytmu")
plt.show()

# %%
df_wav_cbc_3000_3keys = pd.DataFrame(pd.read_csv('../features_cbc/features_cbc_3000/features_cbc_3000_3keys_csv/features_wav_cbc.csv'))
df_wav_cbc_3000_3keys
# Out:
#              file_name   format   entropy        mean     variance    std_dev  \
# 0     file0852.wav.enc  wav_cbc  7.998002  127.821814  5472.537639  73.976602
# 1     file0842.wav.enc  wav_cbc  7.997970  127.399418  5451.806915  73.836352
# 2     file1033.wav.enc  wav_cbc  7.999546  127.211817  5451.046476  73.831203
# 3     file1023.wav.enc  wav_cbc  7.999359  127.339807  5461.464537  73.901722
# 4     file0993.wav.enc  wav_cbc  7.999639  127.355404  5468.373414  73.948451
# ...                ...      ...       ...         ...          ...        ...
# 2995  file0273.wav.enc  wav_cbc  7.997821  127.898473  5492.134744  74.108938
# 2996  file0436.wav.enc  wav_cbc  7.999547  127.622611  5472.327280  73.975180
# 2997  file0426.wav.enc  wav_cbc  7.999271  127.630554  5468.200614  73.947283
# 2998  file0105.wav.enc  wav_cbc  7.999560  127.813543  5458.932575  73.884590
# 2999  file0115.wav.enc  wav_cbc  7.999211  127.407576  5455.399805  73.860678
#
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_wav_cbc_3000_3keys["algorithm"].unique()):
    subset = df_wav_cbc_3000_3keys[df_wav_cbc_3000_3keys["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.wav, trzy klucze szyfrujące na algorytm, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_wav_cbc_3000_3keys["algorithm"], y=df_wav_cbc_3000_3keys["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie CBC dla różnych algorytmów i 3000 plików *.wav szyfrowanych trzema kluczami dla każdego algorytmu")
plt.show()

# %% [markdown]
# Diagrams for 1000 files per format in ECB mode (6 keys per algorithm)

# %%
df_all_cbc_3000_6keys = pd.DataFrame(pd.read_csv(
    '../features_cbc/features_cbc_3000/features_cbc_3000_6keys_csv/features_all.csv'))
df_all_cbc_3000_6keys
# Out:
#                 file_name    format   entropy        mean     variance  \
# 0         file0873.py.enc  pyth_cbc  7.955724  127.728565  5559.080881
# 1         file0973.py.enc  pyth_cbc  7.869084  126.760989  5721.768423
# 2         file0666.py.enc  pyth_cbc  7.975942  127.798337  5515.074749
# 3         file0766.py.enc  pyth_cbc  7.939765  128.635575  5432.916001
# 4         file0605.py.enc  pyth_cbc  7.958636  127.641667  5411.530856
# ...                   ...       ...       ...         ...          ...
# 17995  image_0519.bmp.enc   bmp_cbc  7.999492  127.652242  5462.472277
# 17996  image_0471.bmp.enc   bmp_cbc  7.998456  127.288216  5470.863738
# 17997  image_0509.bmp.enc   bmp_cbc  7.999156  127.429229  5469.746607
# 17998  image_0152.bmp.enc   bmp_cbc  7.998335  127.251795  5444.541172
# 17999  image_0142.bmp.enc   bmp_cbc  7.997820  127.157989  5464.527900
#
#          std_dev  skewness  kurtosis    energy        rms  ...  histogram_247  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_all_cbc_3000_6keys["algorithm"].unique()):
    subset = df_all_cbc_3000_6keys[df_all_cbc_3000_6keys["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.xlim(0,255)
#plt.title(
    #"Histogram bajtów dla różnych algorytmów i wszystkich formatów plików, 3000 plików na format, sześć kluczy szyfrujących na algorytm, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_all_cbc_3000_6keys["algorithm"], y=df_all_cbc_3000_6keys["entropy"])
plt.xticks(rotation=45)
#plt.title(
    #"Entropia w trybie CBC dla różnych algorytmów i wszystkich formatów plików, 3000 plików na format, sześć kluczy szyfrujących na algorytm")
plt.show()

# %%
import matplotlib.pyplot as plt

algorithms = df_all_cbc_3000_6keys["algorithm"].unique()
algorithms = [algo for algo in algorithms if algo != "NONE"]

plt.figure(figsize=(15, 5))
for algo in algorithms:
    subset = df_all_cbc_3000_6keys[df_all_cbc_3000_6keys["algorithm"] == algo]
    avg_hist = subset.iloc[:, 9:265].mean()
    plt.plot(range(256), avg_hist, label=algo)
plt.xlim(0, 255)
plt.xlabel("Wartości bajtów")
plt.ylabel("Średnia liczność")
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_bmp_cbc_3000_6keys = pd.DataFrame(pd.read_csv(
    '../features_cbc/features_cbc_3000/features_cbc_3000_6keys_csv/features_bmp_cbc.csv'))
df_bmp_cbc_3000_6keys
# Out:
#                file_name   format   entropy        mean     variance  \
# 0     image_1064.bmp.enc  bmp_cbc  7.999504  127.416551  5454.016120
# 1     image_1074.bmp.enc  bmp_cbc  7.999014  127.478355  5467.891910
# 2     image_0770.bmp.enc  bmp_cbc  7.998907  127.590959  5486.801618
# 3     image_0608.bmp.enc  bmp_cbc  7.999189  127.119514  5469.126197
# 4     image_0760.bmp.enc  bmp_cbc  7.998990  127.601001  5464.123755
# ...                  ...      ...       ...         ...          ...
# 2995  image_0519.bmp.enc  bmp_cbc  7.999492  127.652242  5462.472277
# 2996  image_0471.bmp.enc  bmp_cbc  7.998456  127.288216  5470.863738
# 2997  image_0509.bmp.enc  bmp_cbc  7.999156  127.429229  5469.746607
# 2998  image_0152.bmp.enc  bmp_cbc  7.998335  127.251795  5444.541172
# 2999  image_0142.bmp.enc  bmp_cbc  7.997820  127.157989  5464.527900
#
#         std_dev  skewness  kurtosis    energy        rms  ...  histogram_247  \
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_bmp_cbc_3000_6keys["algorithm"].unique()):
    subset = df_bmp_cbc_3000_6keys[df_bmp_cbc_3000_6keys["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.bmp, sześć kluczy szyfrujących na algorytm, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_bmp_cbc_3000_6keys["algorithm"], y=df_bmp_cbc_3000_6keys["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie CBC dla różnych algorytmów i 3000 plików *.bmp szyfrowanych sześcioma kluczami dla każdego algorytmu")
plt.show()

# %%
df_csv_cbc_3000_6keys = pd.DataFrame(pd.read_csv(
    '../features_cbc/features_cbc_3000/features_cbc_3000_6keys_csv/features_csv_cbc.csv'))
df_csv_cbc_3000_6keys
# Out:
#              file_name   format   entropy        mean     variance    std_dev  \
# 0     file0715.csv.enc  csv_cbc  5.964996  116.430556  5218.245177  72.237422
# 1     file0705.csv.enc  csv_cbc  6.178126  127.443182  4951.905863  70.369779
# 2     file1179.csv.enc  csv_cbc  5.946928  129.187500  5571.177344  74.640320
# 3     file1001.csv.enc  csv_cbc  6.327797  141.778846  6246.422245  79.034311
# 4     file1169.csv.enc  csv_cbc  6.383161  129.535714  5026.820153  70.900072
# ...                ...      ...       ...         ...          ...        ...
# 2995  file0414.csv.enc  csv_cbc  6.408012  125.046875  4952.247803  70.372209
# 2996  file0251.csv.enc  csv_cbc  6.436732  129.616071  5104.915099  71.448689
# 2997  file0329.csv.enc  csv_cbc  5.893620  125.775000  6170.599375  78.553163
# 2998  file0241.csv.enc  csv_cbc  6.046928  116.912500  4790.854844  69.216001
# 2999  file0339.csv.enc  csv_cbc  6.243766  134.593750  4972.074544  70.512939
#
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_csv_cbc_3000_6keys["algorithm"].unique()):
    subset = df_csv_cbc_3000_6keys[df_csv_cbc_3000_6keys["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.csv, sześć kluczy szyfrujących na algorytm, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_csv_cbc_3000_6keys["algorithm"], y=df_csv_cbc_3000_6keys["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie CBC dla różnych algorytmów i 3000 plików *.csv szyfrowanych sześcioma kluczami dla każdego algorytmu")
plt.show()

# %%
df_html_cbc_3000_6keys = pd.DataFrame(pd.read_csv(
    '../features_cbc/features_cbc_3000/features_cbc_3000_6keys_csv/features_html_cbc.csv'))
df_html_cbc_3000_6keys
# Out:
#               file_name    format   entropy        mean     variance  \
# 0     file1072.html.enc  html_cbc  7.977116  126.852998  5410.574860
# 1     file1073.html.enc  html_cbc  7.960590  127.509026  5517.276724
# 2     file0674.html.enc  html_cbc  7.939779  127.924662  5385.634527
# 3     file0882.html.enc  html_cbc  7.896548  129.834067  5501.870794
# 4     file0883.html.enc  html_cbc  7.981901  127.151648  5470.852817
# ...                 ...       ...       ...         ...          ...
# 2995  file0536.html.enc  html_cbc  7.813769  128.314394  5509.526156
# 2996  file0205.html.enc  html_cbc  7.979870  128.053019  5468.289952
# 2997  file0063.html.enc  html_cbc  7.840392  129.190141  5464.742015
# 2998  file0062.html.enc  html_cbc  7.976366  127.873273  5398.959914
# 2999  file0204.html.enc  html_cbc  7.979727  126.633069  5467.310930
#
#         std_dev  skewness  kurtosis   energy        rms  ...  histogram_247  \
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_html_cbc_3000_6keys["algorithm"].unique()):
    subset = df_html_cbc_3000_6keys[df_html_cbc_3000_6keys["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.html, sześć kluczy szyfrujących na algorytm")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_html_cbc_3000_6keys["algorithm"], y=df_html_cbc_3000_6keys["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie ECB dla różnych algorytmów i 1800 plików *.html szyfrowanych sześcioma kluczami dla każdego algorytmu")
plt.show()

# %%
df_pyth_cbc_3000_6keys = pd.DataFrame(pd.read_csv(
    '../features_cbc/features_cbc_3000/features_cbc_3000_6keys_csv/features_pyth_cbc.csv'))
df_pyth_cbc_3000_6keys
# Out:
#             file_name    format   entropy        mean     variance    std_dev  \
# 0     file0873.py.enc  pyth_cbc  7.955724  127.728565  5559.080881  74.559244
# 1     file0973.py.enc  pyth_cbc  7.869084  126.760989  5721.768423  75.642372
# 2     file0666.py.enc  pyth_cbc  7.975942  127.798337  5515.074749  74.263549
# 3     file0766.py.enc  pyth_cbc  7.939765  128.635575  5432.916001  73.708317
# 4     file0605.py.enc  pyth_cbc  7.958636  127.641667  5411.530856  73.563108
# ...               ...       ...       ...         ...          ...        ...
# 2995  file0593.py.enc  pyth_cbc  7.973331  126.708861  5425.359067  73.657037
# 2996  file0108.py.enc  pyth_cbc  7.972541  127.663663  5425.163621  73.655710
# 2997  file0008.py.enc  pyth_cbc  7.976419  126.956870  5419.068388  73.614322
# 2998  file0116.py.enc  pyth_cbc  7.972485  128.074920  5476.725290  74.004900
# 2999  file0016.py.enc  pyth_cbc  7.981634  127.920280  5449.386777  73.819962
#
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_pyth_cbc_3000_6keys["algorithm"].unique()):
    subset = df_pyth_cbc_3000_6keys[df_pyth_cbc_3000_6keys["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.py, sześć kluczy szyfrujących na algorytm, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_pyth_cbc_3000_6keys["algorithm"], y=df_pyth_cbc_3000_6keys["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie CBC dla różnych algorytmów i 3000 plików *.py szyfrowanych sześcioma kluczami dla każdego algorytmu")
plt.show()

# %%
df_txt_cbc_3000_6keys = pd.DataFrame(pd.read_csv(
    '../features_cbc/features_cbc_3000/features_cbc_3000_6keys_csv/features_txt_cbc.csv'))
df_txt_cbc_3000_6keys
# Out:
#              file_name   format   entropy        mean     variance    std_dev  \
# 0     file0867.txt.enc  txt_cbc  7.980554  126.997820  5507.579115  74.213066
# 1     file0877.txt.enc  txt_cbc  7.980339  127.141393  5414.396423  73.582582
# 2     file0712.txt.enc  txt_cbc  7.964698  127.288676  5391.062998  73.423859
# 3     file0702.txt.enc  txt_cbc  7.964838  127.567396  5540.010051  74.431244
# 4     file1006.txt.enc  txt_cbc  7.965272  128.879340  5486.057490  74.067925
# ...                ...      ...       ...         ...          ...        ...
# 2995  file0246.txt.enc  txt_cbc  7.943691  128.050658  5405.387565  73.521341
# 2996  file0397.txt.enc  txt_cbc  7.917348  126.770592  5460.461462  73.894935
# 2997  file0387.txt.enc  txt_cbc  7.953196  126.000000  5460.046748  73.892129
# 2998  file0189.txt.enc  txt_cbc  7.970860  129.097187  5535.732562  74.402504
# 2999  file0199.txt.enc  txt_cbc  7.565098  132.459677  5468.099181  73.946597
#
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_txt_cbc_3000_6keys["algorithm"].unique()):
    subset = df_txt_cbc_3000_6keys[df_txt_cbc_3000_6keys["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 3000 plików *.txt, sześć kluczy szyfrujących na algorytm, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_txt_cbc_3000_6keys["algorithm"], y=df_txt_cbc_3000_6keys["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie ECB dla różnych algorytmów i 3000 plików *.txt szyfrowanych sześcioma kluczami dla każdego algorytmu, tryb CBC")
plt.show()

# %%
df_wav_cbc_3000_6keys = pd.DataFrame(pd.read_csv(
    '../features_cbc/features_cbc_3000/features_cbc_3000_6keys_csv/features_wav_cbc.csv'))
df_wav_cbc_3000_6keys
# Out:
#              file_name   format   entropy        mean     variance    std_dev  \
# 0     file0852.wav.enc  wav_cbc  7.997752  127.568981  5461.797045  73.903972
# 1     file0842.wav.enc  wav_cbc  7.998013  127.634540  5481.452598  74.036833
# 2     file1033.wav.enc  wav_cbc  7.999581  127.497105  5461.076980  73.899100
# 3     file1023.wav.enc  wav_cbc  7.999234  127.537343  5457.686782  73.876158
# 4     file0993.wav.enc  wav_cbc  7.999569  127.279740  5464.808229  73.924341
# ...                ...      ...       ...         ...          ...        ...
# 2995  file0273.wav.enc  wav_cbc  7.998281  128.051557  5468.737928  73.950916
# 2996  file0436.wav.enc  wav_cbc  7.999470  127.375867  5466.536350  73.936029
# 2997  file0426.wav.enc  wav_cbc  7.999310  127.385700  5454.578649  73.855119
# 2998  file0105.wav.enc  wav_cbc  7.999472  127.522969  5451.532341  73.834493
# 2999  file0115.wav.enc  wav_cbc  7.999321  127.345046  5467.440670  73.942144
#
# ...

# %%
plt.figure(figsize=(15, 5))
for i, algo in enumerate(df_wav_cbc_3000_6keys["algorithm"].unique()):
    subset = df_wav_cbc_3000_6keys[df_wav_cbc_3000_6keys["algorithm"] == algo].iloc[0, 9:265]  # Kolumny histogramu
    plt.plot(range(256), subset, label=algo)

plt.legend()
plt.title("Histogram bajtów dla różnych algorytmów, 1800 plików *.wav, sześć kluczy szyfrujących na algorytm, tryb CBC")
plt.xlabel("Wartość bajtów")
plt.ylabel("Liczność")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x=df_wav_cbc_3000_6keys["algorithm"], y=df_wav_cbc_3000_6keys["entropy"])
plt.xticks(rotation=45)
plt.title("Entropia w trybie CBC dla różnych algorytmów i 1800 plików *.wav szyfrowanych sześcioma kluczami dla każdego algorytmu")
plt.show()
